# %%
import math
import numpy as np
import torch
import librosa
import torch.nn as nn
from transformers import Wav2Vec2Processor
from transformers.models.wav2vec2.modeling_wav2vec2 import (
    Wav2Vec2Model,
    Wav2Vec2PreTrainedModel,
)

class EmotionModel(Wav2Vec2PreTrainedModel):

    def __init__(self, config):
        super().__init__(config)
        self.config = config
        self.wav2vec2 = Wav2Vec2Model(config)
        self.init_weights()

    def forward(self, input_values):
        outputs = self.wav2vec2(input_values)
        hidden_states = outputs[0]  # (batch_size, sequence_length, hidden_size)
        return hidden_states
    
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_name = 'audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim'
processor = Wav2Vec2Processor.from_pretrained(model_name)
audio_embedder = EmotionModel.from_pretrained(model_name).to(device)

def process_audio(signal: np.ndarray, sampling_rate: int) -> np.ndarray:
    inputs = processor(signal, sampling_rate=sampling_rate, return_tensors="pt", padding=True)
    input_values = inputs["input_values"].to(device)
    
    with torch.no_grad():
        outputs = audio_embedder(input_values)
        embeddings = outputs
        
    return embeddings.detach().cpu().numpy()

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=10000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        pos = torch.arange(0, max_len, dtype=torch.float32).unsqueeze(1)
        div = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(pos * div)
        pe[:, 1::2] = torch.cos(pos * div)
        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        x = x + self.pe[:, :x.size(1), :]
        return x
    
class PositionalEncoding_per(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        pos = torch.arange(0, max_len, dtype=torch.float32).unsqueeze(1)
        div = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(pos * div)
        pe[:, 1::2] = torch.cos(pos * div)
        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        x = x + self.pe[:, :x.size(1), :]
        return x

class TransformerRegressor(nn.Module):
    def __init__(self, input_size, d_model, num_layers, num_heads, dim_feedforward, dropout, num_targets):
        super().__init__()
        self.input_proj = nn.Linear(input_size, d_model)
        self.pos_enc = PositionalEncoding_per(d_model)
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=num_heads,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            activation='relu'
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.head = nn.Linear(d_model, num_targets)

    def forward(self, x, lengths):
        x = self.input_proj(x)
        x = self.pos_enc(x)
        x = x.transpose(0, 1) 
        lengths_cpu = lengths.cpu()
        mask = self._generate_padding_mask(lengths_cpu, x.size(0)).to(x.device)
        x = self.encoder(x, src_key_padding_mask=mask)
        x = x.transpose(0, 1)
        pooled = []
        for i, L in enumerate(lengths_cpu):
            if L > 0:
                pooled.append(x[i, :L].mean(dim=0))
            else:
                pooled.append(torch.zeros(x.size(-1), device=x.device))
        pooled = torch.stack(pooled, dim=0)
        return self.head(pooled)

    @staticmethod
    def _generate_padding_mask(lengths, max_len):
        mask = torch.arange(max_len).expand(len(lengths), max_len) >= lengths.unsqueeze(1)
        return mask


class TransformerClassifier(nn.Module):
    def __init__(self,
                 input_dim: int,
                 d_model: int,
                 num_heads: int,
                 num_layers: int,
                 dim_feedforward: int,
                 num_classes: int,
                 dropout: float = 0.1):
        super().__init__()
        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_enc = PositionalEncoding(d_model)
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=num_heads,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            activation='relu'
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.dropout = nn.Dropout(dropout)
        self.classifier = nn.Linear(d_model, num_classes)

    def forward(self, x, lengths):
        x = self.input_proj(x)                      
        x = self.pos_enc(x)

        x = x.transpose(0, 1)
        mask = self._generate_padding_mask(lengths, x.size(0))
        x = self.transformer(x, src_key_padding_mask=mask)
        x = x.transpose(0, 1)         
        pooled = torch.stack([
            x[i, :lengths[i], :].mean(dim=0) if lengths[i] > 0
            else torch.zeros(x.size(2), device=x.device)
            for i in range(x.size(0))
        ], dim=0)
        return self.classifier(self.dropout(pooled))

    @staticmethod
    def _generate_padding_mask(lengths, max_len):
        bs = lengths.size(0)
        mask = torch.arange(max_len, device=lengths.device).expand(bs, max_len)
        return mask >= lengths.unsqueeze(1)

class FusionTransformer(nn.Module):
    def __init__(self, emo_enc, per_enc, config):
        super().__init__()
        for p in emo_enc.parameters(): p.requires_grad = False
        for p in per_enc.parameters(): p.requires_grad = False

        self.emo_enc = emo_enc
        self.per_enc = per_enc

        h = config['hidden_dim']
        d = config['dropout']
        heads = config['tr_heads']

        self.emo_proj = nn.Sequential(
            nn.Linear(emo_enc.output_dim, h),
            nn.LayerNorm(h),
            nn.Dropout(d)
        )
        self.per_proj = nn.Sequential(
            nn.Linear(per_enc.output_dim, h),
            nn.LayerNorm(h),
            nn.Dropout(d)
        )

        self.mha_e2p = nn.MultiheadAttention(embed_dim=h, num_heads=heads, dropout=d, batch_first=True)
        self.mha_p2e = nn.MultiheadAttention(embed_dim=h, num_heads=heads, dropout=d, batch_first=True)

        self.emo_head = nn.Sequential(
            nn.Linear(h*2,   h),
            nn.LayerNorm(h),
            nn.SiLU(),
            nn.Dropout(d),
            nn.Linear(h, config['num_emotions'])
        )
        self.per_head = nn.Sequential(
            nn.Linear(h*2,   h),
            nn.LayerNorm(h),
            nn.SiLU(),
            nn.Dropout(d),
            nn.Linear(h, config['num_traits'])
        )

    def forward(self, emo_input=None, per_input=None):
        base_emo_logits = base_per_scores = None
        if emo_input is not None:
            x_e, len_e = emo_input
            feat_e = self.emo_enc.extract_features(x_e, len_e)  
            base_emo_logits = self.emo_enc(x_e, len_e)        
            emo_emd = self.emo_proj(feat_e)                     
        if per_input is not None:
            x_p, len_p = per_input
            feat_p = self.per_enc.extract_features(x_p, len_p)  
            base_per_scores = self.per_enc(x_p, len_p)      
            per_emd = self.per_proj(feat_p)                   

        if emo_input is not None and per_input is not None:
            attn_e2p, _ = self.mha_e2p(query=emo_emd, key=per_emd, value=per_emd)
            emo_emd = emo_emd + attn_e2p

            attn_p2e, _ = self.mha_p2e(query=per_emd, key=emo_emd, value=emo_emd)
            per_emd = per_emd + attn_p2e

            fe = emo_emd.mean(dim=1)  
            fp = per_emd.mean(dim=1)  
            cat = torch.cat([fe, fp], dim=-1)  

            emo_new = self.emo_head(cat) 
            per_new = self.per_head(cat) 

            final_emo = (emo_new + base_emo_logits) / 2
            final_per = (per_new + base_per_scores) / 2

            return {'emotion': final_emo, 'personality': final_per}

        elif emo_input is not None:
            return {'emotion': base_emo_logits}
        else:
            return {'personality': base_per_scores}


def load_pretrained_emotion_encoder(path, device):
    enc = TransformerClassifier(
        input_dim=1024,
        d_model=128,
        num_heads=4,
        num_layers=3,
        dim_feedforward=512,
        num_classes=7,
        dropout=0.2
    ).to(device)

    ck = torch.load(path, map_location=device)
    enc.load_state_dict(ck)
    enc.eval()

    enc.output_dim = enc.input_proj.out_features  

    def extract_features(x, lengths):
        h = enc.input_proj(x)           
        h = enc.pos_enc(h)          
        h = h.transpose(0, 1)          
        mask = TransformerClassifier._generate_padding_mask(lengths, h.size(0))
        h = enc.transformer(h, src_key_padding_mask=mask) 
        h = h.transpose(0, 1)          
        return h

    enc.extract_features = extract_features
    return enc


def load_pretrained_personality_encoder(path, device):
    enc = TransformerRegressor(
        input_size=1024,
        d_model=256,
        num_heads=4,
        num_layers=3,
        dim_feedforward=512,
        num_targets=5,
        dropout=0.3
    ).to(device)

    ck = torch.load(path, map_location=device)
    enc.load_state_dict(ck)
    enc.eval()

    enc.output_dim = enc.input_proj.out_features  

    def extract_features(x, lengths):
        h = enc.input_proj(x)          
        h = enc.pos_enc(h)
        h = h.transpose(0, 1)          
        mask = TransformerRegressor._generate_padding_mask(lengths.cpu(), h.size(0)).to(h.device)
        h = enc.encoder(h, src_key_padding_mask=mask) 
        h = h.transpose(0, 1)          
        return h

    enc.extract_features = extract_features
    return enc

def load_fusion_model(
    fusion_ckpt_path: str,
    emo_encoder_ckpt: str,
    per_encoder_ckpt: str,
    device: str = 'cpu'
):
    device = torch.device(device)
    emo_enc = load_pretrained_emotion_encoder(emo_encoder_ckpt, device)
    per_enc = load_pretrained_personality_encoder(per_encoder_ckpt, device)
    ckpt       = torch.load(fusion_ckpt_path, map_location=device)
    best_cfg   = ckpt['config']
    state_dict = ckpt['state_dict']
    model = FusionTransformer(emo_enc, per_enc, best_cfg).to(device)
    model.load_state_dict(state_dict)
    model.eval()
    return model, device

def run_inference(
    model: FusionTransformer,
    device: torch.device,
    embedding: np.ndarray
):
    if embedding.ndim == 3 and embedding.shape[0] == 1:
        emb = embedding[0]  
    elif embedding.ndim == 2:
        emb = embedding    

    x = torch.tensor(emb, dtype=torch.float32).unsqueeze(0).to(device) 
    lengths = torch.tensor([emb.shape[0]], dtype=torch.long).to(device)

    with torch.no_grad():
        out = model(emo_input=(x, lengths), per_input=(x, lengths))
        emo_logits = out['emotion'].cpu().numpy().squeeze(0)
        per_scores = out['personality'].cpu().numpy().squeeze(0)
        emo_probs  = torch.softmax(torch.tensor(emo_logits), dim=-1).numpy()
    return emo_probs, per_scores

def extract_embeddings(audio_path: str) -> np.ndarray:
        signal, sr = librosa.load(audio_path, sr=16000)
        emb = process_audio(signal, sr)
        return emb

if __name__ == "__main__":
    FUSION_CKPT = "best_fusion_overall_trans.pt"
    EMO_ENC_CKPT = "final_best_model_uni_trans.pt"
    PER_ENC_CKPT = "best_trans_fiv2.pt"

    model, device = load_fusion_model(
        FUSION_CKPT, EMO_ENC_CKPT, PER_ENC_CKPT, device='cpu'
    )
    
    emo_names = ['Neutral', 'Anger', 'Disgust', 'Fear', 'Happiness', 'Sadness', 'Surprise']
    pers_names = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Neuroticism']
    
    emb = extract_embeddings("your_audio.wav")
    emo_probs, per_scores = run_inference(model, device, emb)
    print("Emotion")
    for name, v in zip(emo_names, emo_probs):
        print(f"  {name}: {v:.4f}")
        
    print("Personality")   
    for name, v in zip(pers_names, per_scores):
        print(f"  {name}: {v:.4f}")

# %%
import math
import numpy as np
import torch
import librosa
import torch.nn as nn
from transformers import Wav2Vec2Processor
from transformers.models.wav2vec2.modeling_wav2vec2 import (
    Wav2Vec2Model,
    Wav2Vec2PreTrainedModel,
)

class EmotionModel(Wav2Vec2PreTrainedModel):

    def __init__(self, config):
        super().__init__(config)
        self.config = config
        self.wav2vec2 = Wav2Vec2Model(config)
        self.init_weights()

    def forward(self, input_values):
        outputs = self.wav2vec2(input_values)
        hidden_states = outputs[0]  # (batch_size, sequence_length, hidden_size)
        return hidden_states
    
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_name = 'audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim'
processor = Wav2Vec2Processor.from_pretrained(model_name)
audio_embedder = EmotionModel.from_pretrained(model_name).to(device)

def process_audio(signal: np.ndarray, sampling_rate: int) -> np.ndarray:
    inputs = processor(signal, sampling_rate=sampling_rate, return_tensors="pt", padding=True)
    input_values = inputs["input_values"].to(device)
    
    with torch.no_grad():
        outputs = audio_embedder(input_values)
        embeddings = outputs
        
    return embeddings.detach().cpu().numpy()


class CustomMambaBlock(nn.Module):
    def __init__(self, d_model, dropout=0.1):
        super().__init__()
        self.in_proj = nn.Linear(d_model, d_model)
        self.s_B = nn.Linear(d_model, d_model)
        self.s_C = nn.Linear(d_model, d_model)
        self.out_proj = nn.Linear(d_model, d_model)
        self.norm = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)
        self.act = nn.ReLU()
    def forward(self, x):
        x_in = x
        x = self.in_proj(x)
        x = x + self.s_B(x) + self.s_C(x)
        x = self.act(x)
        x = self.out_proj(x)
        x = self.dropout(x)
        return self.norm(x + x_in)

class CustomMambaClassifier(nn.Module):
    def __init__(self, input_size=1024, d_model=256, num_layers=2, num_classes=7, dropout=0.1):
        super().__init__()
        self.input_proj = nn.Linear(input_size, d_model)
        self.blocks = nn.ModuleList([CustomMambaBlock(d_model, dropout) for _ in range(num_layers)])
        self.fc = nn.Linear(d_model, num_classes)
    def forward(self, x, lengths):
        x = self.input_proj(x)
        for blk in self.blocks: x = blk(x)
        pooled = [x[i, :L].mean(dim=0) if L>0 else torch.zeros(x.size(-1), device=x.device)
                  for i, L in enumerate(lengths)]
        return self.fc(torch.stack(pooled, dim=0))
    

class CustomMambaRegressor(nn.Module):
    def __init__(self, input_size, d_model, num_layers, num_targets, dropout=0.1):
        super().__init__()
        self.input_proj = nn.Linear(input_size, d_model)
        self.blocks = nn.ModuleList([CustomMambaBlock(d_model, dropout) for _ in range(num_layers)])
        self.head = nn.Linear(d_model, num_targets)
    def forward(self, x, lengths):
        x = self.input_proj(x)
        for blk in self.blocks: x = blk(x)
        pooled = [x[i, :L].mean(dim=0) if L>0 else torch.zeros(x.size(-1), device=x.device)
                  for i, L in enumerate(lengths)]
        return self.head(torch.stack(pooled, dim=0))

class FusionTransformer(nn.Module):
    def __init__(self, emo_enc, per_enc, config):
        super().__init__()
       
        for p in emo_enc.parameters(): p.requires_grad = False
        for p in per_enc.parameters(): p.requires_grad = False

        self.emo_enc = emo_enc
        self.per_enc = per_enc

        h = config['hidden_dim']
        d = config['dropout']
        heads = config['tr_heads']

        
        self.emo_proj = nn.Sequential(
            nn.Linear(emo_enc.output_dim, h),
            nn.LayerNorm(h),
            nn.Dropout(d)
        )
        self.per_proj = nn.Sequential(
            nn.Linear(per_enc.output_dim, h),
            nn.LayerNorm(h),
            nn.Dropout(d)
        )

        
        self.mha_e2p = nn.MultiheadAttention(embed_dim=h, num_heads=heads, dropout=d, batch_first=True)
        self.mha_p2e = nn.MultiheadAttention(embed_dim=h, num_heads=heads, dropout=d, batch_first=True)

  
        self.emo_head = nn.Sequential(
            nn.Linear(h*2,   h),
            nn.LayerNorm(h),
            nn.SiLU(),
            nn.Dropout(d),
            nn.Linear(h, config['num_emotions'])
        )
        self.per_head = nn.Sequential(
            nn.Linear(h*2,   h),
            nn.LayerNorm(h),
            nn.SiLU(),
            nn.Dropout(d),
            nn.Linear(h, config['num_traits'])
        )

    def forward(self, emo_input=None, per_input=None):
        
        base_emo_logits = base_per_scores = None
        if emo_input is not None:
            x_e, len_e = emo_input
            feat_e = self.emo_enc.extract_features(x_e, len_e)   
            base_emo_logits = self.emo_enc(x_e, len_e)         
            emo_emd = self.emo_proj(feat_e)                    
        if per_input is not None:
            x_p, len_p = per_input
            feat_p = self.per_enc.extract_features(x_p, len_p) 
            base_per_scores = self.per_enc(x_p, len_p)          
            per_emd = self.per_proj(feat_p)                    
            
        if emo_input is not None and per_input is not None:
           
            attn_e2p, _ = self.mha_e2p(query=emo_emd, key=per_emd, value=per_emd)
            emo_emd = emo_emd + attn_e2p
          
            attn_p2e, _ = self.mha_p2e(query=per_emd, key=emo_emd, value=emo_emd)
            per_emd = per_emd + attn_p2e

            fe = emo_emd.mean(dim=1) 
            fp = per_emd.mean(dim=1) 
            cat = torch.cat([fe, fp], dim=-1) 
            
            emo_new = self.emo_head(cat)   
            per_new = self.per_head(cat)
            
            final_emo = (emo_new + base_emo_logits) / 2
            final_per = (per_new + base_per_scores) / 2

            return {'emotion': final_emo, 'personality': final_per}

        elif emo_input is not None:
            return {'emotion': base_emo_logits}
        else:
            return {'personality': base_per_scores}

def load_pretrained_emotion_encoder(path, device):
    enc = CustomMambaClassifier(input_size=1024, d_model=256, num_layers=3, num_classes=7, dropout=0.2).to(device)
    ck = torch.load(path, map_location=device)
    enc.load_state_dict(ck['model_state_dict'])
    enc.output_dim = 256

    def extract_features(x, lengths):
        h = enc.input_proj(x)               
        for blk in enc.blocks:
            h = blk(h)                       
        return h

    enc.extract_features = extract_features
    enc.eval()
    return enc

def load_pretrained_personality_encoder(path, device):
    enc = CustomMambaRegressor(input_size=1024, d_model=256, num_layers=3, num_targets=5, dropout=0.2).to(device)
    ck = torch.load(path, map_location=device)
    enc.load_state_dict(ck)
    enc.output_dim = 256

    def extract_features(x, lengths):
        h = enc.input_proj(x)               
        for blk in enc.blocks:
            h = blk(h)                       
        return h

    enc.extract_features = extract_features
    enc.eval()
    return enc


def load_fusion_model(
    fusion_ckpt_path: str,
    emo_encoder_ckpt: str,
    per_encoder_ckpt: str,
    device: str = 'cpu'
):
    device = torch.device(device)
    emo_enc = load_pretrained_emotion_encoder(emo_encoder_ckpt, device)
    per_enc = load_pretrained_personality_encoder(per_encoder_ckpt, device)
    ckpt       = torch.load(fusion_ckpt_path, map_location=device)
    best_cfg   = ckpt['config']
    state_dict = ckpt['state_dict']
    model = FusionTransformer(emo_enc, per_enc, best_cfg).to(device)
    model.load_state_dict(state_dict)
    model.eval()
    return model, device

def run_inference(
    model: FusionTransformer,
    device: torch.device,
    embedding: np.ndarray
):
    if embedding.ndim == 3 and embedding.shape[0] == 1:
        emb = embedding[0]  
    elif embedding.ndim == 2:
        emb = embedding    

    x = torch.tensor(emb, dtype=torch.float32).unsqueeze(0).to(device) 
    lengths = torch.tensor([emb.shape[0]], dtype=torch.long).to(device)

    with torch.no_grad():
        out = model(emo_input=(x, lengths), per_input=(x, lengths))
        emo_logits = out['emotion'].cpu().numpy().squeeze(0)
        per_scores = out['personality'].cpu().numpy().squeeze(0)
        emo_probs  = torch.softmax(torch.tensor(emo_logits), dim=-1).numpy()
    return emo_probs, per_scores

def extract_embeddings(audio_path: str) -> np.ndarray:
        signal, sr = librosa.load(audio_path, sr=16000)
        emb = process_audio(signal, sr)
        return emb

if __name__ == "__main__":
    FUSION_CKPT = "../modalities/audio/checkpoints/best_fusion_overall_mamba.pt"
    EMO_ENC_CKPT = "../modalities/audio/checkpoints/final_best_model_uni_mamba.pt"
    PER_ENC_CKPT = "../modalities/audio/checkpoints/best_mamba_regressor.pth"

    model, device = load_fusion_model(
        FUSION_CKPT, EMO_ENC_CKPT, PER_ENC_CKPT, device='cpu'
    )
    
    emo_names = ['Neutral', 'Anger', 'Disgust', 'Fear', 'Happiness', 'Sadness', 'Surprise']
    pers_names = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Neuroticism']
    
    emb = extract_embeddings("E:/FirstImpressionsV2/audio/train/_0bg1TLPP-I.004.wav")
    emo_probs, per_scores = run_inference(model, device, emb)
    print("Emotion")
    for name, v in zip(emo_names, emo_probs):
        print(f"  {name}: {v:.4f}")
        
    print("Personality")   
    for name, v in zip(pers_names, per_scores):
        print(f"  {name}: {v:.4f}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 261
#     258 emo_names = ['Neutral', 'Anger', 'Disgust', 'Fear', 'Happiness', 'Sadness', 'Surprise']
#     259 pers_names = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Neuroticism']
# --> 261 emb = extract_embeddings("E:/FirstImpressionsV2/audio/train/_0bg1TLPP-I.004.wav", device)
#     262 emo_probs, per_scores = run_inference(model, device, emb)
#     263 print("Emotion")
#
# Cell In[11], line 246, in extract_embeddings(audio_path, device)
#     244 def extract_embeddings(audio_path: str, device: torch.device) -> np.ndarray:
#     245         signal, sr = librosa.load(audio_path, sr=16000)
# --> 246         emb = process_audio(signal, sr, device)
#     247         return emb
#
# Cell In[11], line 37, in process_audio(signal, sampling_rate, device)
#      34 input_values = inputs["input_values"].to(device)
#      36 with torch.no_grad():
# ---> 37     outputs = audio_embedder(input_values)
#      38     embeddings = outputs
#      40 return embeddings.detach().cpu().numpy()
#
# File c:\Prgrm\EAAI_2025\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Prgrm\EAAI_2025\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[11], line 21, in EmotionModel.forward(self, input_values)
#      20 def forward(self, input_values):
# ---> 21     outputs = self.wav2vec2(input_values)
#      22     hidden_states = outputs[0]  # (batch_size, sequence_length, hidden_size)
#      23     return hidden_states
#
# File c:\Prgrm\EAAI_2025\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Prgrm\EAAI_2025\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Prgrm\EAAI_2025\.venv\Lib\site-packages\transformers\models\wav2vec2\modeling_wav2vec2.py:1714, in Wav2Vec2Model.forward(self, input_values, attention_mask, mask_time_indices, output_attentions, output_hidden_states, return_dict)
#    1709 output_hidden_states = (
#    1710     output_hidden_states if output_hidden_states is not None else self.config.output_hidden_states
#    1711 )
#    1712 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1714 extract_features = self.feature_extractor(input_values)
#    1715 extract_features = extract_features.transpose(1, 2)
#    1717 if attention_mask is not None:
#    1718     # compute reduced attention_mask corresponding to feature vectors
#
# File c:\Prgrm\EAAI_2025\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Prgrm\EAAI_2025\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Prgrm\EAAI_2025\.venv\Lib\site-packages\transformers\models\wav2vec2\modeling_wav2vec2.py:437, in Wav2Vec2FeatureEncoder.forward(self, input_values)
#     432         hidden_states = self._gradient_checkpointing_func(
#     433             conv_layer.__call__,
#     434             hidden_states,
#     435         )
#     436     else:
# --> 437         hidden_states = conv_layer(hidden_states)
#     439 return hidden_states
#
# File c:\Prgrm\EAAI_2025\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Prgrm\EAAI_2025\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Prgrm\EAAI_2025\.venv\Lib\site-packages\transformers\models\wav2vec2\modeling_wav2vec2.py:306, in Wav2Vec2LayerNormConvLayer.forward(self, hidden_states)
#     305 def forward(self, hidden_states):
# --> 306     hidden_states = self.conv(hidden_states)
#     308     hidden_states = hidden_states.transpose(-2, -1)
#     309     hidden_states = self.layer_norm(hidden_states)
#
# File c:\Prgrm\EAAI_2025\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Prgrm\EAAI_2025\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Prgrm\EAAI_2025\.venv\Lib\site-packages\torch\nn\modules\conv.py:375, in Conv1d.forward(self, input)
#     374 def forward(self, input: Tensor) -> Tensor:
# --> 375     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Prgrm\EAAI_2025\.venv\Lib\site-packages\torch\nn\modules\conv.py:370, in Conv1d._conv_forward(self, input, weight, bias)
#     358 if self.padding_mode != "zeros":
#     359     return F.conv1d(
#     360         F.pad(
#     361             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     368         self.groups,
#     369     )
# --> 370 return F.conv1d(
#     371     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     372 )
#
# RuntimeError: Input type (torch.FloatTensor) and weight type (torch.cuda.FloatTensor) should be the same or input should be a MKLDNN tensor and weight is a dense tensor

# %%
import os
import subprocess

# Убедимся, что ffmpeg доступен
def check_ffmpeg():
    try:
        subprocess.run(["ffmpeg", "-version"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    except FileNotFoundError:
        raise RuntimeError("FFmpeg не найден. Установи его и добавь в PATH, гений.")

# %%
import os
import subprocess
from tqdm import tqdm  # 

def convert_video_to_audio(file_path: str, root_video_dir: str, root_audio_dir: str, sr: int = 16000) -> str:
    """
    Конвертирует видео в аудио. WAV сохраняется в аудиопапке с сохранением структуры.
    """
    rel_path = os.path.relpath(file_path, root_video_dir)
    path_save = os.path.join(root_audio_dir, os.path.splitext(rel_path)[0] + ".wav")
    os.makedirs(os.path.dirname(path_save), exist_ok=True)

    if not os.path.exists(path_save):
        ffmpeg_command = f"ffmpeg -y -i \"{file_path}\" -async 1 -vn -acodec pcm_s16le -ar {sr} \"{path_save}\""
        subprocess.call(ffmpeg_command, shell=True)
    return path_save

def batch_convert_all_videos(root_video_dir: str, root_audio_dir: str):
    """
    Обходит все видеофайлы в root_video_dir и сохраняет WAV в root_audio_dir.
    """
    video_files = []
    for root, _, files in os.walk(root_video_dir):
        for file in files:
            if file.lower().endswith((".mp4", ".avi", ".mov", ".mkv")):
                full_path = os.path.join(root, file)
                video_files.append(full_path)

    for file_path in tqdm(video_files, desc="Конвертация видео в аудио", unit="файл"):
        wav_path = convert_video_to_audio(file_path, root_video_dir, root_audio_dir)

if __name__ == "__main__":
    video_dir = r"E:/CMU-MOSEI/video"
    audio_dir = r"E:/CMU-MOSEI/audio"
    batch_convert_all_videos(video_dir, audio_dir)
# Out:
# Конвертация видео в аудио: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 22788/22788 [40:04<00:00,  9.48файл/s]

# %%
import os
import shutil

def move_and_sort_files(source_root: str, target_audio_root: str, target_video_root: str):
    for split in ["dev", "test", "train"]:
        split_dir = os.path.join(source_root, split)
        if not os.path.exists(split_dir):
            continue

        for root, _, files in os.walk(split_dir):
            for file in files:
                ext = os.path.splitext(file)[1].lower()
                if ext not in [".mp4", ".wav"]:
                    continue

                # Определим куда переместить
                if ext == ".mp4":
                    target_dir = os.path.join(target_video_root, split)
                else:  # .wav
                    target_dir = os.path.join(target_audio_root, split)

                os.makedirs(target_dir, exist_ok=True)
                src_path = os.path.join(root, file)
                dst_path = os.path.join(target_dir, file)

                try:
                    shutil.move(src_path, dst_path)
                    print(f"Перемещено: {dst_path}")
                except Exception as e:
                    print(f"Ошибка при перемещении {src_path}: {e}")

# Использование:
move_and_sort_files(
    source_root="E:/FirstImpressionsV2",
    target_audio_root="E:/FirstImpressionsV2/audio",
    target_video_root="E:/FirstImpressionsV2/video"
)
# Out:
# Перемещено: E:/FirstImpressionsV2/video\dev\-DOqN0d8KHw.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\-DOqN0d8KHw.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\05l5bteT_qA.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\05l5bteT_qA.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\3ccY8jYkI5o.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\3ccY8jYkI5o.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\4yogPbHFQ9o.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\4yogPbHFQ9o.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\54JawR1x0II.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\54JawR1x0II.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\7b9DirXrkHo.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\7b9DirXrkHo.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\8hW6WfYBP18.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\8hW6WfYBP18.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\8OGiv7FetSQ.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\8OGiv7FetSQ.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\8pM3X-xsD4s.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\8pM3X-xsD4s.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\9QGTbcqb2tM.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\9QGTbcqb2tM.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\9UUtf0_ZR14.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\9UUtf0_ZR14.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\C2MEPH7x9m0.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\C2MEPH7x9m0.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\cjbh1lfr43c.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\cjbh1lfr43c.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\d4cPiUXpGbc.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\d4cPiUXpGbc.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\d8skGb2ycio.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\d8skGb2ycio.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\dB-kMg4t-V8.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\dB-kMg4t-V8.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\dQOeQYWIgm8.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\dQOeQYWIgm8.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\DSYiLCGNDP0.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\DSYiLCGNDP0.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\dvCKoyBG1pE.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\dvCKoyBG1pE.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\EelHLfeSJfM.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\EelHLfeSJfM.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\F0kidNe_RSo.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\F0kidNe_RSo.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Fi1ILrwQpSY.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Fi1ILrwQpSY.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\fkDqn2muw-A.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\fkDqn2muw-A.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\G7QTNbKbu_4.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\G7QTNbKbu_4.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\gZzB49daFfA.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\gZzB49daFfA.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\HhC2cGFFZeY.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\HhC2cGFFZeY.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\JBiq9X_-r84.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\JBiq9X_-r84.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\jFx6AEw6viQ.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\jFx6AEw6viQ.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\JKDEEwxZwrw.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\JKDEEwxZwrw.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\jVGTEDAYWZ8.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\jVGTEDAYWZ8.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\knpgk7LAMb0.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\knpgk7LAMb0.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\KVepk_9iPEU.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\KVepk_9iPEU.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\KYvbRwTCtaU.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\KYvbRwTCtaU.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\lErjGxBb1Bk.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\lErjGxBb1Bk.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\LfvTKoMYLEE.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\LfvTKoMYLEE.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\LRU4jLhKaak.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\LRU4jLhKaak.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\LtTR6elruhU.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\LtTR6elruhU.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\m7zdWVDT-34.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\m7zdWVDT-34.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\mAjagYWuT7A.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\mAjagYWuT7A.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\mfGhtr0zy3k.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\mfGhtr0zy3k.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\MsGTYOOp4hE.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\MsGTYOOp4hE.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\m_9aygJNij8.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\m_9aygJNij8.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\nfEhF5GBQpo.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\nfEhF5GBQpo.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\nlIrqbcvqLk.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\nlIrqbcvqLk.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\nndDX4RgU1w.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\nndDX4RgU1w.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\nUbhRInpVbA.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\nUbhRInpVbA.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\OIRq4d8IyKc.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\OIRq4d8IyKc.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\OuE91U_n04E.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\OuE91U_n04E.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\p5QXPhJS8Ks.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\p5QXPhJS8Ks.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\PooFvZH6fK0.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\PooFvZH6fK0.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\PQBGDxYGaXU.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\PQBGDxYGaXU.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\PWM-bKcs2p8.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\PWM-bKcs2p8.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\p_mu11crx-s.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\p_mu11crx-s.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\qjU3GX3jgSY.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\qjU3GX3jgSY.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\QTtTAFqT-no.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\QTtTAFqT-no.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\qyHn_jrNL48.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\qyHn_jrNL48.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\RCr48dXuZYE.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\RCr48dXuZYE.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\SgWtBK48AjE.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\SgWtBK48AjE.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\sHafPWyXs6k.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\sHafPWyXs6k.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\SUI6WNryjqw.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\SUI6WNryjqw.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\t0_DAgeU4nM.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\t0_DAgeU4nM.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\tYpxPqwle5k.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\tYpxPqwle5k.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\uoLDJJMK5Gw.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\uoLDJJMK5Gw.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\VJuVsi6G96s.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\VJuVsi6G96s.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\vOEQlAMABWM.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\vOEQlAMABWM.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\VuadgOz6T7s.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\VuadgOz6T7s.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\VxtZDXM0cuQ.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\VxtZDXM0cuQ.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\WD1WsbooU2w.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\WD1WsbooU2w.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\wFZJ3gTKwwM.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\wFZJ3gTKwwM.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\x0mD5kr2hu4.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\x0mD5kr2hu4.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\X1EjfXX3NTk.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\X1EjfXX3NTk.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\xfLVThCzEEk.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\xfLVThCzEEk.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\XhgDsQlEnuU.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\XhgDsQlEnuU.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\XQZ5M9oLkXw.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\XQZ5M9oLkXw.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Y8gv_ZK3w4A.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Y8gv_ZK3w4A.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\YdxS3f4HXaA.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\YdxS3f4HXaA.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\YygvfVxOWP8.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\YygvfVxOWP8.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\ZaihsIQZCx8.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\ZaihsIQZCx8.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Z_STuUHKQTg.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Z_STuUHKQTg.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\_fJcW5234bY.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\_fJcW5234bY.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\-6otZ7M-Mro.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\-6otZ7M-Mro.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\-8asrRvfJWA.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\-8asrRvfJWA.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\0axZSeaUbfs.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\0axZSeaUbfs.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\0iQIfGnKflc.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\0iQIfGnKflc.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\1mODTfLRGdI.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\1mODTfLRGdI.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\1sjXuXtx9-E.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\1sjXuXtx9-E.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\2TMl5EMrdVI.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\2TMl5EMrdVI.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\2x8GZaBY6TM.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\2x8GZaBY6TM.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\3HA2W1s4oP8.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\3HA2W1s4oP8.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\836kYlEs9GI.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\836kYlEs9GI.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\8hW6WfYBP18.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\8hW6WfYBP18.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\8s0R8r6UsU0.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\8s0R8r6UsU0.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\9SGTRbePKLI.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\9SGTRbePKLI.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\9uMpKla2OQM.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\9uMpKla2OQM.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\AobPtpyKat8.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\AobPtpyKat8.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\AP0aklGHino.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\AP0aklGHino.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\AvuGsnkWjt8.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\AvuGsnkWjt8.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\B1efbNxLPe8.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\B1efbNxLPe8.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\B77ZCcCMrkM.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\B77ZCcCMrkM.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\bFwtVtZodIg.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\bFwtVtZodIg.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\bN2IM-rqZlc.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\bN2IM-rqZlc.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Bn5QwANp5LM.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Bn5QwANp5LM.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Bo-mrL28d8M.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Bo-mrL28d8M.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\bt-ev53zZWE.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\bt-ev53zZWE.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\c4XnKouozXU.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\c4XnKouozXU.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\cA3KzjBNr4M.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\cA3KzjBNr4M.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\CFK8ib0aWe8.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\CFK8ib0aWe8.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\cgT-3CHBmKs.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\cgT-3CHBmKs.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Cvuu76B-bxA.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Cvuu76B-bxA.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\DGCGeNlA-Ww.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\DGCGeNlA-Ww.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\DvWzedL3QCk.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\DvWzedL3QCk.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\EAMHqNxa9yY.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\EAMHqNxa9yY.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\EHPZNxP5mN8.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\EHPZNxP5mN8.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\F0VbEO_0Ybc.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\F0VbEO_0Ybc.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\fBMKlYUjA9E.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\fBMKlYUjA9E.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\fk_ggmC872E.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\fk_ggmC872E.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\FPfgwGsy8dE.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\FPfgwGsy8dE.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\hquzfo9MVDo.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\hquzfo9MVDo.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\itQ2wSlXqCw.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\itQ2wSlXqCw.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\IV01x2GS61g.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\IV01x2GS61g.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\kco35S1k5Ks.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\kco35S1k5Ks.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\khCsAN1Bk_I.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\khCsAN1Bk_I.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\kPXVZD3ac8s.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\kPXVZD3ac8s.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\kUpkeJDcxaE.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\kUpkeJDcxaE.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\LKc69Et2Jg8.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\LKc69Et2Jg8.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\mAjagYWuT7A.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\mAjagYWuT7A.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\MDoZUDTSayc.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\MDoZUDTSayc.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\mEQBB6XsJFk.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\mEQBB6XsJFk.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\nlIrqbcvqLk.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\nlIrqbcvqLk.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\NpkHOa4uIn4.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\NpkHOa4uIn4.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\OhHg1lyxe4I.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\OhHg1lyxe4I.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\okSmKH2k5lE.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\okSmKH2k5lE.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Or2_bP4lWYI.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Or2_bP4lWYI.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\oYiWW-Qc0rs.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\oYiWW-Qc0rs.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\p-OcwNFQB0U.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\p-OcwNFQB0U.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\pkwzo1OkEmY.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\pkwzo1OkEmY.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\QOIP8pV85D8.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\QOIP8pV85D8.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Qz_cjgCtDcM.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Qz_cjgCtDcM.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\rag7X1kTyBc.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\rag7X1kTyBc.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\RDdB2AqJpog.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\RDdB2AqJpog.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\rLEfJzLcVdg.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\rLEfJzLcVdg.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\RuRn2t7iPSc.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\RuRn2t7iPSc.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\rV6Vdn-JrTA.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\rV6Vdn-JrTA.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\s0MKUEnyHSE.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\s0MKUEnyHSE.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\SRjhmQTPOmA.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\SRjhmQTPOmA.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Ssy7T1T0yKg.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Ssy7T1T0yKg.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\U22Jy0m5xSQ.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\U22Jy0m5xSQ.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\U2RemWUyjts.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\U2RemWUyjts.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\utv9RBNcL5w.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\utv9RBNcL5w.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\voB6O-ky9cA.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\voB6O-ky9cA.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\WuIKjBb7s4Q.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\WuIKjBb7s4Q.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\wuTgJGTEK-0.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\wuTgJGTEK-0.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\WZnLayQeIZ0.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\WZnLayQeIZ0.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\xHb5_bc1JOA.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\xHb5_bc1JOA.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\xYXVkQOmSfk.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\xYXVkQOmSfk.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\y4Ej1YSEQf0.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\y4Ej1YSEQf0.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\YdxS3f4HXaA.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\YdxS3f4HXaA.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\YGrCXe2-fVk.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\YGrCXe2-fVk.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Zwu5Y5r3Lrs.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Zwu5Y5r3Lrs.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\_IS6GFmQYj4.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\_IS6GFmQYj4.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\-9BZ8A9U7TE.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\-9BZ8A9U7TE.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\-agCXYgb7pI.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\-agCXYgb7pI.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\0VnZngec8sc.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\0VnZngec8sc.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\19pTUX8KfYM.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\19pTUX8KfYM.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\1pm5uoU85FI.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\1pm5uoU85FI.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\1yIGI42lzak.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\1yIGI42lzak.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\3WoXkI06zGk.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\3WoXkI06zGk.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\4sCa35TOxgs.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\4sCa35TOxgs.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\54K75EhiTEk.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\54K75EhiTEk.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\5BPGRteF64Y.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\5BPGRteF64Y.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\6NjuNY4LfQc.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\6NjuNY4LfQc.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\7wsksuXYoMY.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\7wsksuXYoMY.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\9pGJyf1MXLY.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\9pGJyf1MXLY.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\9ydyJKZBWiA.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\9ydyJKZBWiA.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\adBtc3XrSsg.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\adBtc3XrSsg.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\aIwWcLojoh0.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\aIwWcLojoh0.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\aptKaxP81xA.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\aptKaxP81xA.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\AR3UwbmgKuQ.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\AR3UwbmgKuQ.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\BlvmREgt2C0.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\BlvmREgt2C0.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\cdtZKwM5NIM.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\cdtZKwM5NIM.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\CpmR-91GxmY.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\CpmR-91GxmY.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\CpmR-91GxmY.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\CpmR-91GxmY.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\cQRFb-xa4Vc.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\cQRFb-xa4Vc.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\d4cPiUXpGbc.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\d4cPiUXpGbc.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\datcFOBWYxc.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\datcFOBWYxc.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\dmycfNpiWCE.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\dmycfNpiWCE.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\DzqJmiQjsZ4.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\DzqJmiQjsZ4.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\fKrX-KXgXYM.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\fKrX-KXgXYM.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\fUf2XzWpSVo.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\fUf2XzWpSVo.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\GBp9YtOw_eQ.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\GBp9YtOw_eQ.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\ins5QQc2dR0.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\ins5QQc2dR0.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\jd9_8OPxM3A.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\jd9_8OPxM3A.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\jd9_8OPxM3A.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\jd9_8OPxM3A.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Jhz5ssCKaug.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Jhz5ssCKaug.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\jPpZkVzQywk.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\jPpZkVzQywk.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\jpRnHWTLDUs.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\jpRnHWTLDUs.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\jrhvXPaXo-0.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\jrhvXPaXo-0.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\jZl3Rq1MRQg.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\jZl3Rq1MRQg.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\k2buv6xZ4_o.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\k2buv6xZ4_o.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\KmHe8urs3LI.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\KmHe8urs3LI.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\L5PkZA1ErYY.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\L5PkZA1ErYY.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\lK8qOASUwFE.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\lK8qOASUwFE.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\lLWOcztaIBI.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\lLWOcztaIBI.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\lnawWqnGpMc.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\lnawWqnGpMc.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\me9kzWYVEoI.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\me9kzWYVEoI.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\mZzWhUI0CP0.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\mZzWhUI0CP0.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\N5YT0FFd3-s.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\N5YT0FFd3-s.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\nmZRXxKPPuQ.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\nmZRXxKPPuQ.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\o7J2fWIJndQ.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\o7J2fWIJndQ.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\o7rFDFvW300.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\o7rFDFvW300.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Oe7ItP7gS4w.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Oe7ItP7gS4w.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\OeGMd58Wgsk.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\OeGMd58Wgsk.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\oGa05H9UXxU.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\oGa05H9UXxU.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\P63CUj9KnSw.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\P63CUj9KnSw.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\PHmkN1cPl10.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\PHmkN1cPl10.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\PHUlL5ZzX5U.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\PHUlL5ZzX5U.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Q4z4GRUtccE.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Q4z4GRUtccE.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Qu81v9Aybv4.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Qu81v9Aybv4.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\R-qB2FX7ZbE.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\R-qB2FX7ZbE.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\R42dmIPCXwo.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\R42dmIPCXwo.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\r4BGKIXrD9c.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\r4BGKIXrD9c.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\RB9vu-0Y_Fk.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\RB9vu-0Y_Fk.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Rwsss8y1bf0.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Rwsss8y1bf0.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\SNEoE1c-k64.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\SNEoE1c-k64.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\t0AupkXkkZw.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\t0AupkXkkZw.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\tcmYlyeqwuI.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\tcmYlyeqwuI.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\TTx4lC7LLcI.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\TTx4lC7LLcI.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\uCJNAX_b9mc.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\uCJNAX_b9mc.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Ui1ajQU5Ib8.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Ui1ajQU5Ib8.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\VmXZ2jMWuvk.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\VmXZ2jMWuvk.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\VugKq4gOi50.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\VugKq4gOi50.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\WTzDOt2GO1M.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\WTzDOt2GO1M.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\wVpjBxCirAQ.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\wVpjBxCirAQ.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\xEmwNv4OxGE.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\xEmwNv4OxGE.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\XvV4YdhpC2w.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\XvV4YdhpC2w.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\y-0p6fGXLD0.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\y-0p6fGXLD0.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\y-0p6fGXLD0.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\y-0p6fGXLD0.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\YygvfVxOWP8.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\YygvfVxOWP8.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Zdz0TqboSNI.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Zdz0TqboSNI.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\zupxsNi2er8.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\zupxsNi2er8.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\-Wqk9eex6bQ.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\-Wqk9eex6bQ.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\0u56Q_QmxIM.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\0u56Q_QmxIM.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\1m67onLoRwY.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\1m67onLoRwY.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\1XkKu4LBvog.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\1XkKu4LBvog.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\2WuhWF4fAOQ.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\2WuhWF4fAOQ.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\5lqg3tAI9H0.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\5lqg3tAI9H0.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\5LT-hTT4J7s.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\5LT-hTT4J7s.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\7nJPNkWZDOY.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\7nJPNkWZDOY.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\7qGYGbIg45c.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\7qGYGbIg45c.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\8w_oPolxRWQ.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\8w_oPolxRWQ.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\aFVFvJNnFt0.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\aFVFvJNnFt0.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\bJktioZ5Yxk.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\bJktioZ5Yxk.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\blAjqQ0ja8Q.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\blAjqQ0ja8Q.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\c2LeNguVNrI.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\c2LeNguVNrI.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Cng72emlXAM.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Cng72emlXAM.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\CV930dFsubs.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\CV930dFsubs.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\cx8IycWgMVs.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\cx8IycWgMVs.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\d9_YDJdF-7I.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\d9_YDJdF-7I.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\dOFnHXRLEdM.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\dOFnHXRLEdM.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\DXYRJ8PReoE.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\DXYRJ8PReoE.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\DyZlhseSuec.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\DyZlhseSuec.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\EeI8iXLDfc0.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\EeI8iXLDfc0.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\EffEoI1l1zE.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\EffEoI1l1zE.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\ej0RpdM9kJA.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\ej0RpdM9kJA.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\EvZ0esZgPK4.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\EvZ0esZgPK4.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\fBcc1UMtZME.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\fBcc1UMtZME.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\FTk2SCmJI_w.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\FTk2SCmJI_w.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\FwjoTGcsFNg.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\FwjoTGcsFNg.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\fY4tctYZTz8.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\fY4tctYZTz8.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\GcuoyJPO-KU.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\GcuoyJPO-KU.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\GsNZh1TS68g.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\GsNZh1TS68g.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\HH03EXo0TB0.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\HH03EXo0TB0.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\hrat_RJczFM.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\hrat_RJczFM.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\HrddpXxWFns.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\HrddpXxWFns.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\I01_ubtktEQ.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\I01_ubtktEQ.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\JBiq9X_-r84.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\JBiq9X_-r84.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\JxxF9y61ujA.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\JxxF9y61ujA.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\k4eeYoHtnnI.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\k4eeYoHtnnI.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\kSk-rf7a1Ig.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\kSk-rf7a1Ig.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\LGdzP-r_G3U.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\LGdzP-r_G3U.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\M56UFrEgXnI.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\M56UFrEgXnI.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\mfcs3Ta49K8.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\mfcs3Ta49K8.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\modNfUPt3F4.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\modNfUPt3F4.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\MOobNUpfWiY.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\MOobNUpfWiY.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\OovRk5U9_GY.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\OovRk5U9_GY.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\OZlpENU9h28.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\OZlpENU9h28.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\p7-JUvStF4w.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\p7-JUvStF4w.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\pEYFpmjwKC0.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\pEYFpmjwKC0.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Pkgi4--hwfo.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Pkgi4--hwfo.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\PsqpkFKX8co.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\PsqpkFKX8co.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Q9B3SJkH2Q8.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Q9B3SJkH2Q8.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Qa-yF-tByDM.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Qa-yF-tByDM.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\qFYgMFMal_s.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\qFYgMFMal_s.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\QKcx5msA7iA.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\QKcx5msA7iA.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\qVcw5-mm31s.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\qVcw5-mm31s.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\r93dLeVRk3U.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\r93dLeVRk3U.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\RJe5yobV8n4.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\RJe5yobV8n4.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\RtbBc9kI6tE.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\RtbBc9kI6tE.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\rTG9gtci67c.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\rTG9gtci67c.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\RW4a2ERzTO8.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\RW4a2ERzTO8.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\s1DOqsQoN5s.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\s1DOqsQoN5s.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Se3Gts4u1vs.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Se3Gts4u1vs.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\shEsu57CYnA.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\shEsu57CYnA.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\si_gZCrLa4A.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\si_gZCrLa4A.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\sNs4yCA11wk.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\sNs4yCA11wk.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\SYlV95nPTPs.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\SYlV95nPTPs.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\T3v3-2tvV0s.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\T3v3-2tvV0s.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\TmpP2fXeVtk.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\TmpP2fXeVtk.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\U3UaF1aFek4.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\U3UaF1aFek4.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\uDm7iZuX5DQ.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\uDm7iZuX5DQ.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\UQeuBvZNusI.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\UQeuBvZNusI.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\vHIBCKwJLEY.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\vHIBCKwJLEY.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\VmXZ2jMWuvk.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\VmXZ2jMWuvk.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\wBCSJVBr4ZE.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\wBCSJVBr4ZE.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\WT1YjeADatU.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\WT1YjeADatU.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\XuXhY_SCkNI.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\XuXhY_SCkNI.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\YryBLVZgJj0.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\YryBLVZgJj0.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\zDRQAU7MtjA.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\zDRQAU7MtjA.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\_0bg1TLPP-I.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\_0bg1TLPP-I.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\_mvqVnzddCw.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\_mvqVnzddCw.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\-PF2TG2loGc.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\-PF2TG2loGc.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\-R2SZu3SYgM.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\-R2SZu3SYgM.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\-VTqcHNgH7M.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\-VTqcHNgH7M.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\0mym1CooiTE.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\0mym1CooiTE.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\1uC-2TZqplE.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\1uC-2TZqplE.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\1XkKu4LBvog.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\1XkKu4LBvog.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\2fzLibPAtvI.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\2fzLibPAtvI.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\2kqPuht5jTg.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\2kqPuht5jTg.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\3ccY8jYkI5o.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\3ccY8jYkI5o.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\3gUpRQ22vUs.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\3gUpRQ22vUs.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\3tPq9fNOXZQ.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\3tPq9fNOXZQ.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\4lIbWq27O84.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\4lIbWq27O84.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\5kwoq4EZixQ.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\5kwoq4EZixQ.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\6uqXoPJSoPg.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\6uqXoPJSoPg.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\6wHQsN5g2RM.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\6wHQsN5g2RM.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\8i7H-uSCQcc.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\8i7H-uSCQcc.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\8s0R8r6UsU0.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\8s0R8r6UsU0.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\a-nUsP7oETI.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\a-nUsP7oETI.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\ADa9rkwF2uA.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\ADa9rkwF2uA.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\ApPnsnIZozw.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\ApPnsnIZozw.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\CO7vZjYF6Zk.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\CO7vZjYF6Zk.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\DChmTb-c9uM.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\DChmTb-c9uM.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\geji1U2YAvg.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\geji1U2YAvg.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\glgfB3vFewc.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\glgfB3vFewc.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\hG0I7DLSSYg.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\hG0I7DLSSYg.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\HT_8WpgGqjk.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\HT_8WpgGqjk.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\J9WyswA0vow.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\J9WyswA0vow.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\jd9_8OPxM3A.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\jd9_8OPxM3A.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\jKHaHWuaU14.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\jKHaHWuaU14.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\jnEHHvlBgxE.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\jnEHHvlBgxE.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\K3-YXXLR0Ho.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\K3-YXXLR0Ho.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Kbcvurfuvhk.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Kbcvurfuvhk.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\kPXVZD3ac8s.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\kPXVZD3ac8s.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\KYkfjIZEScM.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\KYkfjIZEScM.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\LNM1i-a9q_A.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\LNM1i-a9q_A.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\MajYvFTkKnk.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\MajYvFTkKnk.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\mBdVuEXRlfQ.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\mBdVuEXRlfQ.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\MCqC9VBT4q4.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\MCqC9VBT4q4.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\mZzWhUI0CP0.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\mZzWhUI0CP0.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\N5YT0FFd3-s.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\N5YT0FFd3-s.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\ng42eoHytOA.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\ng42eoHytOA.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\nOFHZ_s7Et4.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\nOFHZ_s7Et4.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\nZC82V87Pm0.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\nZC82V87Pm0.003.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\o2wtRccAgjE.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\o2wtRccAgjE.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Os7L5C-i9Fw.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Os7L5C-i9Fw.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\outvbZgNX58.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\outvbZgNX58.005.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\PsHb4YHooKM.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\PsHb4YHooKM.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\PsqpkFKX8co.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\PsqpkFKX8co.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\qssXr_Fg96o.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\qssXr_Fg96o.001.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\qVcw5-mm31s.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\qVcw5-mm31s.002.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\qYxxTubipSs.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\qYxxTubipSs.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\R6NTuhZtOks.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\R6NTuhZtOks.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\rGNeR3p1jKU.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\rGNeR3p1jKU.004.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\RZgTERiRDjA.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\RZgTERiRDjA.000.wav
# Перемещено: E:/FirstImpressionsV2/video\dev\Sdqg-jn_tBk.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\dev\Sdqg-jn_tBk.003.wav
# ...
# Перемещено: E:/FirstImpressionsV2/video\train\Kq-c6lqGNlo.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\Kq-c6lqGNlo.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\l1L61qbiV2U.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\l1L61qbiV2U.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\Lq4uvcHNiy8.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\Lq4uvcHNiy8.000.wav
# Перемещено: E:/FirstImpressionsV2/video\train\LuLUAwn0aWU.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\LuLUAwn0aWU.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\m2uxFfpb5xU.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\m2uxFfpb5xU.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\mkJjaOADfj4.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\mkJjaOADfj4.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\nCc8XfmSvf8.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\nCc8XfmSvf8.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\Nv0-x4K9YFI.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\Nv0-x4K9YFI.000.wav
# Перемещено: E:/FirstImpressionsV2/video\train\NWlCdMyKlE0.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\NWlCdMyKlE0.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\OcS4H_dFeOc.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\OcS4H_dFeOc.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\OtGJDbI9qkM.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\OtGJDbI9qkM.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\Pb7aNc6Kd40.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\Pb7aNc6Kd40.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\qoztP0w5-Vo.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\qoztP0w5-Vo.000.wav
# Перемещено: E:/FirstImpressionsV2/video\train\QQzeQOoqO20.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\QQzeQOoqO20.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\QsUj_OlGQ-0.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\QsUj_OlGQ-0.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\R-vly7LKotQ.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\R-vly7LKotQ.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\rG8D-A2F8xg.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\rG8D-A2F8xg.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\Rops7WYMCCY.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\Rops7WYMCCY.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\SEELGB_-uWU.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\SEELGB_-uWU.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\sf29orxf4X0.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\sf29orxf4X0.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\shEsu57CYnA.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\shEsu57CYnA.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\sNs4yCA11wk.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\sNs4yCA11wk.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\sqnW6xXYTKg.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\sqnW6xXYTKg.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\sTUJhj154Sc.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\sTUJhj154Sc.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\T1--98_78ns.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\T1--98_78ns.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\t6-ljEWQjW8.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\t6-ljEWQjW8.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\tg0i-zxvQXk.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\tg0i-zxvQXk.000.wav
# Перемещено: E:/FirstImpressionsV2/video\train\Tg8a_iNEamM.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\Tg8a_iNEamM.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\tomb22yfjTc.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\tomb22yfjTc.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\twO6ceVTuII.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\twO6ceVTuII.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\ua5c716lu5s.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\ua5c716lu5s.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\uKy7lHuMQ_o.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\uKy7lHuMQ_o.000.wav
# Перемещено: E:/FirstImpressionsV2/video\train\vOEQlAMABWM.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\vOEQlAMABWM.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\VUgKH9DIs-8.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\VUgKH9DIs-8.000.wav
# Перемещено: E:/FirstImpressionsV2/video\train\w_ExyXsnw2A.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\w_ExyXsnw2A.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\xerGtxpxW6Q.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\xerGtxpxW6Q.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\xpSCu7PgJts.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\xpSCu7PgJts.000.wav
# Перемещено: E:/FirstImpressionsV2/video\train\xRhUBifOWiI.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\xRhUBifOWiI.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\y0UCXXk9tlM.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\y0UCXXk9tlM.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\YP7N98ECZaI.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\YP7N98ECZaI.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\zRiS2gIUc9s.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\zRiS2gIUc9s.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\-DOqN0d8KHw.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\-DOqN0d8KHw.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\0axZSeaUbfs.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\0axZSeaUbfs.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\1cqwKxx6GF8.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\1cqwKxx6GF8.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\1fsFL_qNYlQ.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\1fsFL_qNYlQ.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\1Gn4GX8miWQ.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\1Gn4GX8miWQ.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\1hpZ2ecWqtI.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\1hpZ2ecWqtI.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\1jC4vsQsjwM.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\1jC4vsQsjwM.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\1mODTfLRGdI.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\1mODTfLRGdI.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\2KSBoJZMcMU.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\2KSBoJZMcMU.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\3df_Uk9EmwU.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\3df_Uk9EmwU.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\3pJZOCtAzYE.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\3pJZOCtAzYE.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\3R2LrAKCWr8.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\3R2LrAKCWr8.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\7tlMys6MZ34.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\7tlMys6MZ34.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\8KyS0FKbKfI.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\8KyS0FKbKfI.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\8qG1sMihtPA.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\8qG1sMihtPA.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\AFvUxDwJB84.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\AFvUxDwJB84.000.wav
# Перемещено: E:/FirstImpressionsV2/video\train\AJIphVRpYrg.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\AJIphVRpYrg.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\Arsrkqma4i4.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\Arsrkqma4i4.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\AWe6ZZUmlZw.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\AWe6ZZUmlZw.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\Ay7bZ7Sgx9Q.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\Ay7bZ7Sgx9Q.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\BBSB9OJdb0Q.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\BBSB9OJdb0Q.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\BxdFQhBNZys.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\BxdFQhBNZys.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\czImT1Wn1og.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\czImT1Wn1og.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\dRP8ZaAryro.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\dRP8ZaAryro.000.wav
# Перемещено: E:/FirstImpressionsV2/video\train\dVwDf5N2NRA.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\dVwDf5N2NRA.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\DzqJmiQjsZ4.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\DzqJmiQjsZ4.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\EMNcIRgaDMg.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\EMNcIRgaDMg.000.wav
# Перемещено: E:/FirstImpressionsV2/video\train\encC96iqr9Y.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\encC96iqr9Y.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\fDw_PAgW07o.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\fDw_PAgW07o.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\fpyBDfh7qF0.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\fpyBDfh7qF0.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\fsaslN7xV-w.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\fsaslN7xV-w.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\g24JGYuT74A.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\g24JGYuT74A.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\GR-P1m_Yvm0.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\GR-P1m_Yvm0.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\hF3yR5rmga8.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\hF3yR5rmga8.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\HUxtuDE-YNE.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\HUxtuDE-YNE.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\iAgu-wDe2MQ.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\iAgu-wDe2MQ.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\iPblZBQpafs.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\iPblZBQpafs.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\iW1t-ZiG2rc.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\iW1t-ZiG2rc.000.wav
# Перемещено: E:/FirstImpressionsV2/video\train\jKHaHWuaU14.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\jKHaHWuaU14.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\JoQRNgGQCgY.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\JoQRNgGQCgY.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\k3iu-fhIkeI.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\k3iu-fhIkeI.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\KIJ9IYETe38.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\KIJ9IYETe38.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\knpgk7LAMb0.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\knpgk7LAMb0.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\lsVwEApsljU.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\lsVwEApsljU.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\mBdVuEXRlfQ.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\mBdVuEXRlfQ.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\MBgwyWKYWVM.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\MBgwyWKYWVM.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\MbufNmC0JL0.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\MbufNmC0JL0.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\mfGhtr0zy3k.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\mfGhtr0zy3k.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\mLZw7Hf8AYI.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\mLZw7Hf8AYI.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\ncmnmmmWEpU.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\ncmnmmmWEpU.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\nfN9qJSVank.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\nfN9qJSVank.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\nGe8dIc-ecc.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\nGe8dIc-ecc.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\nghDz0el8iI.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\nghDz0el8iI.000.wav
# Перемещено: E:/FirstImpressionsV2/video\train\nKx64KH7Xks.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\nKx64KH7Xks.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\nUazOUcW_AM.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\nUazOUcW_AM.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\Oe7ItP7gS4w.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\Oe7ItP7gS4w.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\OIRq4d8IyKc.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\OIRq4d8IyKc.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\oLO05QNhhGg.000.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\oLO05QNhhGg.000.wav
# Перемещено: E:/FirstImpressionsV2/video\train\p-OcwNFQB0U.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\p-OcwNFQB0U.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\PRplbrM70sg.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\PRplbrM70sg.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\qkmEt0ofGq8.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\qkmEt0ofGq8.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\qsb1j9bEENs.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\qsb1j9bEENs.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\r2BoxB3kgYk.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\r2BoxB3kgYk.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\Rops7WYMCCY.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\Rops7WYMCCY.003.wav
# Перемещено: E:/FirstImpressionsV2/video\train\ROTx-0q1F9M.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\ROTx-0q1F9M.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\rXoCKj1qwn4.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\rXoCKj1qwn4.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\SCnQFpdklMg.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\SCnQFpdklMg.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\sntohi33U5s.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\sntohi33U5s.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\U9cidDFDTQE.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\U9cidDFDTQE.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\UrOamWOcOwQ.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\UrOamWOcOwQ.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\v68FyWS-Q9s.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\v68FyWS-Q9s.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\V9OuGDPnqHI.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\V9OuGDPnqHI.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\VOeVhXWK7-8.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\VOeVhXWK7-8.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\VxtZDXM0cuQ.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\VxtZDXM0cuQ.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\WATt9OOVZh8.004.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\WATt9OOVZh8.004.wav
# Перемещено: E:/FirstImpressionsV2/video\train\Wbd7QufjK_E.002.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\Wbd7QufjK_E.002.wav
# Перемещено: E:/FirstImpressionsV2/video\train\wK_ExIjn5Q8.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\wK_ExIjn5Q8.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\wTo1uZns2X8.005.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\wTo1uZns2X8.005.wav
# Перемещено: E:/FirstImpressionsV2/video\train\WuHLxhCSnGs.001.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\WuHLxhCSnGs.001.wav
# Перемещено: E:/FirstImpressionsV2/video\train\XmWA7zTJj-c.003.mp4
# Перемещено: E:/FirstImpressionsV2/audio\train\XmWA7zTJj-c.003.wav
